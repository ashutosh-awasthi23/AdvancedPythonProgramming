# %%
import pandas as pd #Importing pandas

# %%
#making a series
series=pd.Series(10,index=["a","b","c"])
series
# Out:
# a    10
# b    10
# c    10
# dtype: int64

# %%
series.sum()
# Out:
# 30

# %%
#making a series using dictionary
data_dict = {'apple': 5, 'banana': 12, 'orange': 2}
series = pd.Series(data_dict)
series
# Out:
# apple      5
# banana    12
# orange     2
# dtype: int64

# %%
#making a series using a list
li = [10, 20, 14, 30]
ser = pd.Series(li)
ser
# Out:
# 0    10
# 1    20
# 2    14
# 3    30
# dtype: int64

# %%
ser.sum()
# Out:
# 74

# %%
ser[ser>=20]
# Out:
# 1    20
# 3    30
# dtype: int64

# %%
import numpy as np
array=np.array([[25,"a"],[26,"b"],[27,'c']])
df=pd.DataFrame(array,columns=['Age','City'])
df
# Out:
#   Age City
# 0  25    a
# 1  26    b
# 2  27    c

# %%
# making a dataframe using list and then dictionary
names=["Ashutosh","Aman","Nipun"]
grade=["A","A","B"]
city=["bareilly","jaipur","chandigarh"]

# %%
data={
    'Name':names,
'Grade':grade,
'City':city
}
print(data)
# Out:
# {'Name': ['Ashutosh', 'Aman', 'Nipun'], 'Grade': ['A', 'A', 'B'], 'City': ['bareilly', 'jaipur', 'chandigarh']}

# %%
df=pd.DataFrame(data)
df
# Out:
#        Name Grade        City
# 0  Ashutosh     A    bareilly
# 1      Aman     A      jaipur
# 2     Nipun     B  chandigarh

# %%
#creating a dataframe from a list of dictionaries

data=[
    
    {'Name':"Ram","Age":25,"City":"Rampur"},
    {"Name":'Bob',"Age":30,"City":'Bareilly'},
    {"Name":"Charlie","Age":40,"City":"spn"}
]
df=pd.DataFrame(data)
df
# Out:
#       Name  Age      City
# 0      Ram   25    Rampur
# 1      Bob   30  Bareilly
# 2  Charlie   40       spn

# %% [markdown]
# #Assignment 1 Reading rows and columns from a csv file

# %%
df=pd.read_csv("assignmentData.csv")
df
# Out:
#    #      Name       City  Age
# 0  1  Ashutosh  New Delhi   23
# 1  2     Shrey  Gorakhpur   23
# 2  3      Aman     Jaipur   23

# %%
df['City']
# Out:
# 0    New Delhi
# 1    Gorakhpur
# 2       Jaipur
# Name: City, dtype: object

# %% [markdown]
# df.iloc[0:1]

# %% [markdown]
# #Assignment2 Create a csv file to hold student data ,roll,no,name,class,marks.Read this data into a dictionary

# %%
df=pd.read_csv("students.csv")
df
# Out:
#    roolno      name   class   marks
# 0       1    Aaryan      12      50
# 1       2     Ankit      11     100
# 2       3     Paras      14      88
# 3       5   Vaibhav      17      60
# 4       6  Abhishek      18      78
# 5       7       Ram      29      90

# %%
df.head()
# Out:
#    roolno      name   class   marks
# 0       1    Aaryan      12      50
# 1       2     Ankit      11     100
# 2       3     Paras      14      88
# 3       5   Vaibhav      17      60
# 4       6  Abhishek      18      78

# %%
df.tail()
# Out:
#    roolno      name   class   marks
# 1       2     Ankit      11     100
# 2       3     Paras      14      88
# 3       5   Vaibhav      17      60
# 4       6  Abhishek      18      78
# 5       7       Ram      29      90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roolno  6 non-null      int64
#  1    name   6 non-null      object
#  2    class  6 non-null      int64
#  3    marks  6 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 320.0+ bytes

# %%
df.describe()
# Out:
#          roolno      class       marks
# count  6.000000   6.000000    6.000000
# mean   4.000000  16.833333   77.666667
# std    2.366432   6.554896   19.158984
# min    1.000000  11.000000   50.000000
# 25%    2.250000  12.500000   64.500000
# 50%    4.000000  15.500000   83.000000
# 75%    5.750000  17.750000   89.500000
# max    7.000000  29.000000  100.000000

# %%
data={'Values':[10,12,12,13,12,14,10,13,13,400]}
df=pd.DataFrame(data)

# %%
Q1=df['Values'].quantile(0.25)
Q3=df['Values'].quantile(0.75)
IQR=Q3-Q1

# %%
lowr_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

# %%
outliers=df[(df["Values"]<lowr_bound)|(df['Values']>upper_bound)]

# %%
print("Outliers:\n",outliers)
# Out:
# Outliers:
#     Values
# 0      10
# 6      10
# 9     400

# %%
data = pd.Series([10,10,20,20,30,40,40])
data
# Out:
# 0    10
# 1    10
# 2    20
# 3    20
# 4    30
# 5    40
# 6    40
# dtype: int64

# %%
print("Average Rank: ")
print(data.rank(method = 'average'))
# Out:
# Average Rank:
# 0    1.5
# 1    1.5
# 2    3.5
# 3    3.5
# 4    5.0
# 5    6.5
# 6    6.5
# dtype: float64

# %%
print("Minimum Rank: ")
print(data.rank(method = 'min'))
# Out:
# Minimum Rank:
# 0    1.0
# 1    1.0
# 2    3.0
# 3    3.0
# 4    5.0
# 5    6.0
# 6    6.0
# dtype: float64

# %%
print("Maximum Rank: ")
print(data.rank(method = 'max'))
# Out:
# Maximum Rank:
# 0    2.0
# 1    2.0
# 2    4.0
# 3    4.0
# 4    5.0
# 5    7.0
# 6    7.0
# dtype: float64

# %%
print("First Rank: ")
print(data.rank(method = 'first'))
# Out:
# First Rank:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    7.0
# dtype: float64

# %%
print("Dense Rank: ")
print(data.rank(method = 'dense'))
# Out:
# Dense Rank:
# 0    1.0
# 1    1.0
# 2    2.0
# 3    2.0
# 4    3.0
# 5    4.0
# 6    4.0
# dtype: float64

# %% [markdown]
# Data Selection

# %%
ds=pd.read_csv("students.csv")
ds
# Out:
#    roolno      name  class  marks
# 0       1    Aaryan     12     50
# 1       2     Ankit     11    100
# 2       3     Paras     14     88
# 3       5   Vaibhav     17     60
# 4       6  Abhishek     18     78
# 5       7       Ram     29     90

# %%
ds['name']
# Out:
# 0      Aaryan
# 1       Ankit
# 2       Paras
# 3     Vaibhav
# 4    Abhishek
# 5         Ram
# Name: name, dtype: object

# %% [markdown]
# Assignment

# %%
df=pd.read_csv("pokemon_data.csv")
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Extracting Coloumns on certain columns ,display 10 rows

# %%
df[['Name','Type 1','Type 2']].head(10)
# Out:
#                         Name Type 1  Type 2
# 0                  Bulbasaur  Grass  Poison
# 1                    Ivysaur  Grass  Poison
# 2                   Venusaur  Grass  Poison
# 3      VenusaurMega Venusaur  Grass  Poison
# 4                 Charmander   Fire     NaN
# 5                 Charmeleon   Fire     NaN
# 6                  Charizard   Fire  Flying
# 7  CharizardMega Charizard X   Fire  Dragon
# 8  CharizardMega Charizard Y   Fire  Flying
# 9                   Squirtle  Water     NaN

# %%
df[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
df[['Name','Type 1']].iloc[5:11]
# Out:
#                          Name Type 1
# 5                  Charmeleon   Fire
# 6                   Charizard   Fire
# 7   CharizardMega Charizard X   Fire
# 8   CharizardMega Charizard Y   Fire
# 9                    Squirtle  Water
# 10                  Wartortle  Water

# %%
df.loc[5:10, ['Name','Type 1']]
# Out:
#                          Name Type 1
# 5                  Charmeleon   Fire
# 6                   Charizard   Fire
# 7   CharizardMega Charizard X   Fire
# 8   CharizardMega Charizard Y   Fire
# 9                    Squirtle  Water
# 10                  Wartortle  Water

# %%
df=pd.read_csv("pokemon_data.csv")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2    HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass     NaN   NaN      49       49
# 1      2                Ivysaur    Grass     NaN   NaN      62       63
# 2      3               Venusaur    Grass  Poison  80.0      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80.0     100      123
# 4      4             Charmander     Fire     NaN  39.0      52       43
# ..   ...                    ...      ...     ...   ...     ...      ...
# 795  719                Diancie     Rock   Fairy  50.0     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50.0     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80.0     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80.0     160       60
# 799  721              Volcanion     Fire   Water  80.0     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df_nan=df.dropna()

# %%
df_nan
# Out:
#        #                       Name   Type 1  Type 2    HP  Attack  Defense  \
# 2      3                   Venusaur    Grass  Poison  80.0      82       83
# 3      3      VenusaurMega Venusaur    Grass  Poison  80.0     100      123
# 6      6                  Charizard     Fire  Flying  78.0      84       78
# 7      6  CharizardMega Charizard X     Fire  Dragon  78.0     130      111
# 8      6  CharizardMega Charizard Y     Fire  Flying  78.0     104       78
# ..   ...                        ...      ...     ...   ...     ...      ...
# 795  719                    Diancie     Rock   Fairy  50.0     100      150
# 796  719        DiancieMega Diancie     Rock   Fairy  50.0     160      110
# 797  720        HoopaHoopa Confined  Psychic   Ghost  80.0     110       60
# 798  720         HoopaHoopa Unbound  Psychic    Dark  80.0     160       60
# 799  721                  Volcanion     Fire   Water  80.0     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2    HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass     NaN   NaN      49       49
# 1      2                Ivysaur    Grass     NaN   NaN      62       63
# 2      3               Venusaur    Grass  Poison  80.0      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80.0     100      123
# 4      4             Charmander     Fire     NaN  39.0      52       43
# ..   ...                    ...      ...     ...   ...     ...      ...
# 795  719                Diancie     Rock   Fairy  50.0     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50.0     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80.0     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80.0     160       60
# 799  721              Volcanion     Fire   Water  80.0     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# df["HP"]=df["HP"].fillna(df["HP"].mean())
# df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-171-c4593c351dce> in <module>
# ----> 1 df["HP"]=df["HP"].fillna(df["HP"].mean())
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
# ...

# %%
#ASSIGNMENT

# %%
df=pd.read_csv("country_vaccinations.csv")

# %%
df["vaccination_rate"]=df["people_vaccinated"]/10000

# %%
df["daily_vaccinations"]=df["daily_vaccinations"].fillna(df["daily_vaccinations"].mean())

# %%
df
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22         -68767887.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 31235     Zimbabwe      ZWE  2021-07-11           1491397.0
# 31236     Zimbabwe      ZWE  2021-07-12           1531868.0
# 31237     Zimbabwe      ZWE  2021-07-13           1575539.0
# 31238     Zimbabwe      ZWE  2021-07-14           1613640.0
# 31239     Zimbabwe      ZWE  2021-07-15           1666862.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
df.drop('source_name',axis=1,inplace=True)

df
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22         -68767887.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 31235     Zimbabwe      ZWE  2021-07-11           1491397.0
# 31236     Zimbabwe      ZWE  2021-07-12           1531868.0
# 31237     Zimbabwe      ZWE  2021-07-13           1575539.0
# 31238     Zimbabwe      ZWE  2021-07-14           1613640.0
# 31239     Zimbabwe      ZWE  2021-07-15           1666862.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
df.sort_values("total_vaccinations",ascending=False)
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 5770      China      CHN  2021-07-15        1.426347e+09                NaN
# 5769      China      CHN  2021-07-14        1.414609e+09                NaN
# 5768      China      CHN  2021-07-13        1.402019e+09                NaN
# 5767      China      CHN  2021-07-12        1.391432e+09                NaN
# 5766      China      CHN  2021-07-11        1.382482e+09                NaN
# ...         ...      ...         ...                 ...                ...
# 31082    Zambia      ZMB  2021-07-06                 NaN                NaN
# 31093  Zimbabwe      ZWE  2021-02-19                 NaN                NaN
# 31094  Zimbabwe      ZWE  2021-02-20                 NaN                NaN
# 31095  Zimbabwe      ZWE  2021-02-21                 NaN                NaN
# 31234  Zimbabwe      ZWE  2021-07-10                 NaN                NaN
#
# ...

# %%
df = df.rename(columns={'iso_code': 'country_code'})
df
# Out:
#            country country_code        date  total_vaccinations  \
# 0      Afghanistan          AFG  2021-02-22         -68767887.0
# 1      Afghanistan          AFG  2021-02-23                 NaN
# 2      Afghanistan          AFG  2021-02-24                 NaN
# 3      Afghanistan          AFG  2021-02-25                 NaN
# 4      Afghanistan          AFG  2021-02-26                 NaN
# ...            ...          ...         ...                 ...
# 31235     Zimbabwe          ZWE  2021-07-11           1491397.0
# 31236     Zimbabwe          ZWE  2021-07-12           1531868.0
# 31237     Zimbabwe          ZWE  2021-07-13           1575539.0
# 31238     Zimbabwe          ZWE  2021-07-14           1613640.0
# 31239     Zimbabwe          ZWE  2021-07-15           1666862.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# ...

# %%
df.index = range(1, len(df) + 1)
df
# Out:
#            country country_code        date  total_vaccinations  \
# 1      Afghanistan          AFG  2021-02-22         -68767887.0
# 2      Afghanistan          AFG  2021-02-23                 NaN
# 3      Afghanistan          AFG  2021-02-24                 NaN
# 4      Afghanistan          AFG  2021-02-25                 NaN
# 5      Afghanistan          AFG  2021-02-26                 NaN
# ...            ...          ...         ...                 ...
# 31236     Zimbabwe          ZWE  2021-07-11           1491397.0
# 31237     Zimbabwe          ZWE  2021-07-12           1531868.0
# 31238     Zimbabwe          ZWE  2021-07-13           1575539.0
# 31239     Zimbabwe          ZWE  2021-07-14           1613640.0
# 31240     Zimbabwe          ZWE  2021-07-15           1666862.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1                    0.0                      NaN                     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31240 entries, 1 to 31240
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              31240 non-null  object
#  1   country_code                         31240 non-null  object
#  2   date                                 31240 non-null  object
#  3   total_vaccinations                   17451 non-null  float64
#  4   people_vaccinated                    16554 non-null  float64
#  5   people_fully_vaccinated              13795 non-null  float64
#  6   daily_vaccinations_raw               14421 non-null  float64
#  7   daily_vaccinations                   31240 non-null  float64
#  8   total_vaccinations_per_hundred       17451 non-null  float64
#  9   people_vaccinated_per_hundred        16554 non-null  float64
#  10  people_fully_vaccinated_per_hundred  13795 non-null  float64
# ...

# %%
df["people_fully_vaccinated"]=df["people_fully_vaccinated"].fillna(0)

# %%
df["vaccines"]=df["vaccines"].replace({"Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing":"mRNA vaccines","Sinopharm/Beijing":"ram"})

# %%
df
# Out:
#            country country_code        date  total_vaccinations  \
# 1      Afghanistan          AFG  2021-02-22         -68767887.0
# 2      Afghanistan          AFG  2021-02-23                 NaN
# 3      Afghanistan          AFG  2021-02-24                 NaN
# 4      Afghanistan          AFG  2021-02-25                 NaN
# 5      Afghanistan          AFG  2021-02-26                 NaN
# ...            ...          ...         ...                 ...
# 31236     Zimbabwe          ZWE  2021-07-11           1491397.0
# 31237     Zimbabwe          ZWE  2021-07-12           1531868.0
# 31238     Zimbabwe          ZWE  2021-07-13           1575539.0
# 31239     Zimbabwe          ZWE  2021-07-14           1613640.0
# 31240     Zimbabwe          ZWE  2021-07-15           1666862.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1                    0.0                      0.0                     NaN
# ...

# %%
df[df['daily_vaccinations']<0] = 0

# %%
df
# Out:
#            country country_code        date  total_vaccinations  \
# 1      Afghanistan          AFG  2021-02-22         -68767887.0
# 2      Afghanistan          AFG  2021-02-23                 NaN
# 3      Afghanistan          AFG  2021-02-24                 NaN
# 4      Afghanistan          AFG  2021-02-25                 NaN
# 5      Afghanistan          AFG  2021-02-26                 NaN
# ...            ...          ...         ...                 ...
# 31236     Zimbabwe          ZWE  2021-07-11           1491397.0
# 31237     Zimbabwe          ZWE  2021-07-12           1531868.0
# 31238     Zimbabwe          ZWE  2021-07-13           1575539.0
# 31239     Zimbabwe          ZWE  2021-07-14           1613640.0
# 31240     Zimbabwe          ZWE  2021-07-15           1666862.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1                    0.0                      0.0                     NaN
# ...
